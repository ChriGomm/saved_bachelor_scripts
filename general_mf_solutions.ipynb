# %%
from sympy import Matrix, I, re, Symbol, conjugate, det, solve, sin, cos, pi,N, init_printing, pprint, nsolve, Function, lambdify, simplify, expand, series, Abs, degree, cancel, diff,sqrt
from sympy.physics.quantum import TensorProduct
init_printing()
x = Symbol('x',real=True)
y = Symbol('y',real=True)
z = Symbol('z',real=True)
d = Symbol('d',real=True)
K = Symbol('K',real=True)
g = Symbol('g',real=True)
G  = Symbol('G',real=True)
w = Symbol('w',real=True)

# %%
eq1 = -d/2*y - (g-G)/2*x + K*x*  (1/2-w/G*y+K/G*(x**2+y**2))
eq2 = d/2*x -(g-G)/2*y -  w* (1/2-w/G*y+K/G*(x**2+y**2))+ K*y*  (1/2-w/G*y+K/G*(x**2+y**2))
eq1 = (eq1*2*G).expand()
eq2 = (eq2*2*G).expand()
eq3 = eq1*y-eq2*x
eq3 = (eq3*2*G).expand()
eq1,  eq2, eq3
# Out:
# ⎛ 2                                    2  3      2    2               2
# ⎝G ⋅x + 1.0⋅G⋅K⋅x - G⋅d⋅y - G⋅g⋅x + 2⋅K ⋅x  + 2⋅K ⋅x⋅y  - 2⋅K⋅w⋅x⋅y, G ⋅y + 1.
#
#                                    2  2        2  3          2          2
# 0⋅G⋅K⋅y + G⋅d⋅x - G⋅g⋅y - G⋅w + 2⋅K ⋅x ⋅y + 2⋅K ⋅y  - 2⋅K⋅w⋅x  - 4⋅K⋅w⋅y  + 2⋅
#
#  2         2    2      2    2        2                3              2
# w ⋅y, - 2⋅G ⋅d⋅x  - 2⋅G ⋅d⋅y  + 2.0⋅G ⋅w⋅x + 4⋅G⋅K⋅w⋅x  + 4⋅G⋅K⋅w⋅x⋅y  - 4⋅G⋅w
#
# 2    ⎞
#  ⋅x⋅y⎠

# %%
eq1.coeff(K,1), eq2.coeff(K,1), eq3.coeff(K,0)
xf = 
# dw1 = diff(eq1,w).expand()
# dx1 = diff(eq1,x).expand()
# dx1.subs([(x,0),(w,0)]), dx1.subs([(x,0),(w,0)])
# d2w1 =diff(dw1,w).expand()
# d2x1 =diff(dx1,x).expand()
# dxw1 =diff(dx1,w).expand()
# Out:
# ⎛                                  2        2       2    2      2    2
# ⎝1.0⋅G⋅x - 2⋅w⋅x⋅y, 1.0⋅G⋅y - 2⋅w⋅x  - 4⋅w⋅y , - 2⋅G ⋅d⋅x  - 2⋅G ⋅d⋅y  + 2.0⋅G
#
# 2            2    ⎞
#  ⋅w⋅x - 4⋅G⋅w ⋅x⋅y⎠

# %%
# Out:
#      2    2      2    2        2                3              2        2
# - 2⋅G ⋅d⋅x  - 2⋅G ⋅d⋅y  + 2.0⋅G ⋅w⋅x + 4⋅G⋅K⋅w⋅x  + 4⋅G⋅K⋅w⋅x⋅y  - 4⋅G⋅w ⋅x⋅y

# %%
sol_y = solve(eq3,y)
eq4 = simplify(series(sol_y[0],w,0,n=3).expand())
# eq4
sol_y
# Out:
# ⎡          ___________________________________________________________________
# ⎢ 2       ╱   ⎛   2  2      2                  2          2        2  2  3
# ⎢w ⋅x - ╲╱  x⋅⎝- G ⋅d ⋅x + G ⋅d⋅w + 4⋅G⋅K⋅d⋅w⋅x  - 2⋅G⋅K⋅w ⋅x - 4⋅K ⋅w ⋅x  + w
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎣                                  -G⋅d + 2⋅K⋅w⋅x
#
# _____            _____________________________________________________________
# 4  ⎞    2       ╱   ⎛   2  2      2                  2          2        2  2
#  ⋅x⎠   w ⋅x + ╲╱  x⋅⎝- G ⋅d ⋅x + G ⋅d⋅w + 4⋅G⋅K⋅d⋅w⋅x  - 2⋅G⋅K⋅w ⋅x - 4⋅K ⋅w ⋅
# ─────, ───────────────────────────────────────────────────────────────────────
#                                          -G⋅d + 2⋅K⋅w⋅x
#
# ___________⎤
#  3    4  ⎞ ⎥
# x  + w ⋅x⎠ ⎥
# ───────────⎥
#            ⎦

# %%
lam = w**2*x/(-G*d + 2*K*w*x)
y_sol = simplify((sol_y[0]-lam).expand())
y_sol, lam
# Out:
# ⎛   ________________________________________________________________________
# ⎜  ╱   ⎛   2  2      2                  2          2        2  2  3    4  ⎞
# ⎜╲╱  x⋅⎝- G ⋅d ⋅x + G ⋅d⋅w + 4⋅G⋅K⋅d⋅w⋅x  - 2⋅G⋅K⋅w ⋅x - 4⋅K ⋅w ⋅x  + w ⋅x⎠
# ⎜───────────────────────────────────────────────────────────────────────────,
# ⎝                               G⋅d - 2⋅K⋅w⋅x
#
#               ⎞
#       2       ⎟
#      w ⋅x     ⎟
# ──────────────⎟
# -G⋅d + 2⋅K⋅w⋅x⎠

# %%
eq1p = (G*(G*x + K*x - d*(y+lam) - g*x)/2 + K**2*x**3 + K**2*x*(y+lam)**2 - K*w*x*(y+lam))/G
eq1p = expand(eq1p)
c = eq1p.coeff(y,1)
eq5 = c*y

eq6 = simplify(expand(eq1p-c*y))
simplify(expand(eq5+eq6-eq1p)), eq1p, eq5, eq6
# Out:
# ⎛                        2  4  3                      2  2  2                3
# ⎜   G⋅x                 K ⋅w ⋅x                    2⋅K ⋅w ⋅x ⋅y           K⋅w
# ⎜0, ─── + ─────────────────────────────────── + ────────────────── - ─────────
# ⎜    2     3  2      2                2  2  2      2                    2
# ⎝         G ⋅d  - 4⋅G ⋅K⋅d⋅w⋅x + 4⋅G⋅K ⋅w ⋅x    - G ⋅d + 2⋅G⋅K⋅w⋅x   - G ⋅d +
#
#   2                       2                       2  3    2    2
# ⋅x          K⋅x        d⋅w ⋅x        d⋅y   g⋅x   K ⋅x    K ⋅x⋅y    K⋅w⋅x⋅y
# ───────── + ─── - ──────────────── - ─── - ─── + ───── + ─────── - ───────, y⋅
#              2    -2⋅G⋅d + 4⋅K⋅w⋅x    2     2      G        G         G
# 2⋅G⋅K⋅w⋅x
#
# ⎛       2  2  2                ⎞                       2  4  3
# ⎜    2⋅K ⋅w ⋅x        d   K⋅w⋅x⎟  G⋅x                 K ⋅w ⋅x
# ⎜────────────────── - ─ - ─────⎟, ─── + ─────────────────────────────────── +
# ⎜   2                 2     G  ⎟   2     3  2      2                2  2  2
# ...

# %%
# # print(simplify((eq6-eq5).expand()))
eq5 = simplify((eq5**2).expand())
eq6= simplify((eq6**2).expand())
for i in range(5):
    print(eq5.coeff(y,i))
eq5 = eq5.coeff(y,2)*y_sol**2
eq5 = simplify(eq5.expand())
# Out:
# 0
# 0
# G**2*d**4/(4*(G**2*d**2 - 4*G*K*d*w*x + 4*K**2*w**2*x**2))
# 0
# 0
# ...

# %%
eq7 =0
for i in range(7):
    print(eq6.coeff(y,i))
    eq7 += eq6.coeff(y,i)*y_sol**i
    eq7 = simplify(expand(eq7))
eq7 = simplify(expand(eq7-eq5))
# Out:
# G**2*x**2/4 + G*K**2*w**4*x**4/(G**3*d**2 - 4*G**2*K*d*w*x + 4*G*K**2*w**2*x**2) + G*K*w**3*x**3/(G**2*d - 2*G*K*w*x) + G*K*x**2/2 + G*d*w**2*x**2/(2*G*d - 4*K*w*x) - G*g*x**2/2 + K**4*w**8*x**6/(G**6*d**4 - 8*G**5*K*d**3*w*x + 24*G**4*K**2*d**2*w**2*x**2 - 32*G**3*K**3*d*w**3*x**3 + 16*G**2*K**4*w**4*x**4) + 2*K**4*w**4*x**6/(G**4*d**2 - 4*G**3*K*d*w*x + 4*G**2*K**2*w**2*x**2) + 2*K**3*w**7*x**5/(G**5*d**3 - 6*G**4*K*d**2*w*x + 12*G**3*K**2*d*w**2*x**2 - 8*G**2*K**3*w**3*x**3) + K**3*w**4*x**4/(G**3*d**2 - 4*G**2*K*d*w*x + 4*G*K**2*w**2*x**2) + 2*K**3*w**3*x**5/(G**3*d - 2*G**2*K*w*x) + 2*K**2*d*w**6*x**4/(2*G**4*d**3 - 12*G**3*K*d**2*w*x + 24*G**2*K**2*d*w**2*x**2 - 16*G*K**3*w**3*x**3) + 2*K**2*d*w**2*x**4/(2*G**2*d - 4*G*K*w*x) - K**2*g*w**4*x**4/(G**3*d**2 - 4*G**2*K*d*w*x + 4*G*K**2*w**2*x**2) + K**2*w**6*x**4/(G**4*d**2 - 4*G**3*K*d*w*x + 4*G**2*K**2*w**2*x**2) + K**2*w**3*x**3/(G**2*d - 2*G*K*w*x) + K**2*x**4 + K**2*x**2/4 + 2*K*d*w**5*x**3/(2*G**3*d**2 - 8*G**2*K*d*w*x + 8*G
# ...

# %%
# simplify(expand(c**2)), simplify(expand(y_sol**2))
eq7
sol_x = solve(eq7,x)
sol_x
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 # simplify(expand(c**2)), simplify(expand(y_sol**2))
#       2 eq7
# ----> 3 sol_x = solve(eq7,x)
#       4 sol_x
#
# File /usr/lib/python3/dist-packages/sympy/solvers/solvers.py:1145, in solve(f, *symbols, **flags)
#    1143         solution = _solve_undetermined(f[0], symbols, flags)
#    1144     if not solution:
# -> 1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
#    1147     linear, solution = _solve_system(f, symbols, **flags)
#
# File /usr/lib/python3/dist-packages/sympy/solvers/solvers.py:1383, in _solve(f, *symbols, **flags)
#    1377 if check:
#    1378     # all solutions have been checked but now we must
#    1379     # check that the solutions do not set denominators
#    1380     # in any factor to zero
# ...

# %%
eq8 = series(expand(eq7),w,0,n=3)
eq8 = expand(eq8)
for i in range(7):
    print(eq8.coeff(x,i))

eq8.removeO()
# Out:
# O(w**3)
# -d*w/4
# G**2/4 + G*K/2 - G*g/2 + K**2/4 - K*g/2 + d**2/4 + g**2/4 + w**2/2 - K*w**2/G - g*w**2/(2*G)
# K**2*w/d + K**3*w/(G*d) - K**2*g*w/(G*d) + K*d*w/G
# 2*K**3*w**2/(G*d**2) + 3*K**4*w**2/(G**2*d**2) - 2*K**3*g*w**2/(G**2*d**2) + 3*K**2*w**2/G**2
# 0
# 0
#  2  2        2        2    2  2    2    3        2    2  2            2  2
# G ⋅x    G⋅K⋅x    G⋅g⋅x    K ⋅x    K ⋅w⋅x    K⋅g⋅x    d ⋅x    d⋅w⋅x   g ⋅x    w
# ───── + ────── - ────── + ───── + ─────── - ────── + ───── - ───── + ───── + ─
#   4       2        2        4        d        2        4       4       4
#
#
# 2  2    3    3      3  2  4    2      3          3      2  2      2  2      4
#  ⋅x    K ⋅w⋅x    2⋅K ⋅w ⋅x    K ⋅g⋅w⋅x    K⋅d⋅w⋅x    K⋅w ⋅x    g⋅w ⋅x    3⋅K ⋅
# ──── + ─────── + ────────── - ───────── + ──────── - ─────── - ─────── + ─────
#  2       G⋅d           2         G⋅d         G          G        2⋅G        2
#                     G⋅d                                                    G ⋅
#
# ...

# %%
eq7.expand()
# Out:
#                4  2  2                                3    2  2
#               G ⋅d ⋅x                              2⋅G ⋅K⋅d ⋅x
# ──────────────────────────────────── + ──────────────────────────────────── -
#    2  2                      2  2  2      2  2                      2  2  2
# 4⋅G ⋅d  - 16⋅G⋅K⋅d⋅w⋅x + 16⋅K ⋅w ⋅x    4⋅G ⋅d  - 16⋅G⋅K⋅d⋅w⋅x + 16⋅K ⋅w ⋅x
#
#               3        3                              3  2    2
#            4⋅G ⋅K⋅d⋅w⋅x                            2⋅G ⋅d ⋅g⋅x
# ──────────────────────────────────── - ──────────────────────────────────── +
#    2  2                      2  2  2      2  2                      2  2  2
# 4⋅G ⋅d  - 16⋅G⋅K⋅d⋅w⋅x + 16⋅K ⋅w ⋅x    4⋅G ⋅d  - 16⋅G⋅K⋅d⋅w⋅x + 16⋅K ⋅w ⋅x
#
#              2  2  2  2                              2  2      3
#             G ⋅K ⋅d ⋅x                            4⋅G ⋅K ⋅d⋅w⋅x
# ──────────────────────────────────── - ──────────────────────────────────── +
# ...

# %%
eq8_2 = (eq8.removeO()).subs(w,0)
eq8_2
eq7_2 = (eq7.expand()).subs(w,0)
# eq7_2 = (eq7).subs([(K,0),(x,0)])
eq7_2
# Out:
#  2  2        2        2    2  2        2    2  2    2  2
# G ⋅x    G⋅K⋅x    G⋅g⋅x    K ⋅x    K⋅g⋅x    d ⋅x    g ⋅x
# ───── + ────── - ────── + ───── - ────── + ───── + ─────
#   4       2        2        4       2        4       4

# %%
dw = diff(eq7,w)
dx = diff(eq7,x)
d2w = diff(dw,w)
d2x = diff(dx,x)
dwx = diff(dw,x)
dw.subs([(w,0),(x,0)]), dx.subs([(w,0),(x,0)])
# Out:
# (0, 0)

# %%
def taylor(func,param,exps_point,order):
    terms =[expand(func)]
    return print(terms)
    expansion= terms[0].subs(param,exps_point)
    for i in range(1,order+1):
        
        der = diff(terms[-1],param).expand()
        terms.append(der)
        expansion += der.subs(param,exps_point)*param**i
        expansion = expansion.expand()
        print(der)
    return expansion

# %%
dK = diff(eq7,K)
dx = diff(eq7,x)
d2K = diff(dK,K)
d2x = diff(dx,x)
dKx = diff(dK,x)
s, dx_0 = dK.subs([(K,0),(x,0)]), dx.subs([(K,0),(x,0)])
s, d2x_0,s =d2K.subs([(K,0),(x,0)]), d2x.subs([(K,0),(x,0)]), dKx.subs([(K,0),(x,0)])

# %%
x_approx_K = -d2x_0*K**2/dx_0
y_approx_K= expand(sol_y[0])
y_approx_K = y_approx_K.subs(x,x_approx_K)
y_approx_K = y_approx_K.expand()
y_final = 0
for i in range(3):
    # i=2
    y_final += y_approx_K.coeff(K,i)*K**i
    # break
y_final=  series(y_approx_K,K,0,n=3)

# simplify(expand(y_final - expand(series(y_approx_K,K,0,n=3))))

# %%
def taylor(func,param,exps_point,order):
    terms =[expand(func)]
    expansion= terms[0].subs(param,exps_point)

    for i in range(1,order+1):
        der = diff(terms[-1],param)
        return i, der
        der = der.expand()
        
        terms.append(der)
        expansion += der.subs(param,exps_point)*param**i
        expansion = expansion.expand()
        print(der)
    return expansion

taylor(y_approx_K,K,0,2)
# Out:
# ⎛
# ⎜
# ⎜
# ⎜
# ⎜      4  2  2   ⎛      4  2  2       3  2  2         2  2  4       2  2  2  2
# ⎜   2⋅G ⋅K ⋅d ⋅w⋅⎝- 12⋅G ⋅K ⋅d  + 24⋅G ⋅K ⋅d ⋅g - 12⋅G ⋅K ⋅d  - 12⋅G ⋅K ⋅d ⋅g
# ⎜1, ──────────────────────────────────────────────────────────────────────────
# ⎜
# ⎜         ⎛   4  3  2      3  3  2      3  4      2  3  4      2  3  2  2
# ⎜         ⎝4⋅G ⋅K ⋅d  - 8⋅G ⋅K ⋅d ⋅g - G ⋅d  + 4⋅G ⋅K ⋅d  + 4⋅G ⋅K ⋅d ⋅g  + 8⋅
# ⎜
# ⎜
# ⎝
#
#
#
#
#
#        2  2  2  2         2  2    2⎞
#  - 24⋅G ⋅K ⋅d ⋅w  + 24⋅G⋅K ⋅d ⋅g⋅w ⎠
# ──────────────────────────────────── + ───────────────────────────────────────
#                              2            4  3  2      3  3  2      3  4
#  2  3  2  2        3  2    2⎞          4⋅G ⋅K ⋅d  - 8⋅G ⋅K ⋅d ⋅g - G ⋅d  + 4⋅G
# G ⋅K ⋅d ⋅w  - 8⋅G⋅K ⋅d ⋅g⋅w ⎠
#
#
#
#
#
#
#
#
#       4    2                                                  3  2  2     ⎛
#    4⋅G ⋅K⋅d ⋅w                                             4⋅G ⋅K ⋅d ⋅g⋅w⋅⎝- 1
# ...

# %%
print(expand(y_approx_K))
# Out:
# 2*G**4*K**2*d**2*w/(4*G**4*K**3*d**2 - 8*G**3*K**3*d**2*g - G**3*d**4 + 4*G**2*K**3*d**4 + 4*G**2*K**3*d**2*g**2 + 8*G**2*K**3*d**2*w**2 - 8*G*K**3*d**2*g*w**2) - 4*G**3*K**2*d**2*g*w/(4*G**4*K**3*d**2 - 8*G**3*K**3*d**2*g - G**3*d**4 + 4*G**2*K**3*d**4 + 4*G**2*K**3*d**2*g**2 + 8*G**2*K**3*d**2*w**2 - 8*G*K**3*d**2*g*w**2) + 2*G**2*K**2*d**4*w/(4*G**4*K**3*d**2 - 8*G**3*K**3*d**2*g - G**3*d**4 + 4*G**2*K**3*d**4 + 4*G**2*K**3*d**2*g**2 + 8*G**2*K**3*d**2*w**2 - 8*G*K**3*d**2*g*w**2) + 2*G**2*K**2*d**2*g**2*w/(4*G**4*K**3*d**2 - 8*G**3*K**3*d**2*g - G**3*d**4 + 4*G**2*K**3*d**4 + 4*G**2*K**3*d**2*g**2 + 8*G**2*K**3*d**2*w**2 - 8*G*K**3*d**2*g*w**2) + 4*G**2*K**2*d**2*w**3/(4*G**4*K**3*d**2 - 8*G**3*K**3*d**2*g - G**3*d**4 + 4*G**2*K**3*d**4 + 4*G**2*K**3*d**2*g**2 + 8*G**2*K**3*d**2*w**2 - 8*G*K**3*d**2*g*w**2) - 4*G*K**2*d**2*g*w**3/(4*G**4*K**3*d**2 - 8*G**3*K**3*d**2*g - G**3*d**4 + 4*G**2*K**3*d**4 + 4*G**2*K**3*d**2*g**2 + 8*G**2*K**3*d**2*w**2 - 8*G*K**3*d**2*g*w**2) - sqrt(-64
# ...

# %%
sqrt_by_hand =expand(-64*G**8*K**10/(d**4*w**2) + 512*G**7*K**10*g/(d**4*w**2) + 32*G**7*K**7/(d**2*w**2) - 256*G**6*K**10/(d**2*w**2) - 1792*G**6*K**10*g**2/(d**4*w**2) - 512*G**6*K**10/d**4 - 192*G**6*K**7*g/(d**2*w**2) - 4*G**6*K**4/w**2 + 1536*G**5*K**10*g/(d**2*w**2) + 3584*G**5*K**10*g**3/(d**4*w**2) + 3584*G**5*K**10*g/d**4 + 96*G**5*K**7/w**2 + 480*G**5*K**7*g**2/(d**2*w**2) + 192*G**5*K**7/d**2 - 8*G**5*K**5/d**2 + 16*G**5*K**4*g/w**2 - 384*G**4*K**10/w**2 - 3840*G**4*K**10*g**2/(d**2*w**2) - 1536*G**4*K**10/d**2 - 4480*G**4*K**10*g**4/(d**4*w**2) - 10752*G**4*K**10*g**2/d**4 - 1536*G**4*K**10*w**2/d**4 - 384*G**4*K**7*g/w**2 - 640*G**4*K**7*g**3/(d**2*w**2) - 960*G**4*K**7*g/d**2 + 32*G**4*K**5*g/d**2 - 8*G**4*K**4*d**2/w**2 - 24*G**4*K**4*g**2/w**2 - 16*G**4*K**4 + 4*G**4*K**4*w**2/d**2 + 2*G**4*K**2 + 1536*G**3*K**10*g/w**2 + 5120*G**3*K**10*g**3/(d**2*w**2) + 7680*G**3*K**10*g/d**2 + 3584*G**3*K**10*g**5/(d**4*w**2) + 17920*G**3*K**10*g**3/d**4 + 9216*G**3*K**10*g*w**2/d**4 + 96*G**3*K**7*d**2/w**2 + 576*G**3*K**7*g**2/w**2 + 384*G**3*K**7 + 480*G**3*K**7*g**4/(d**2*w**2) + 1920*G**3*K**7*g**2/d**2 + 384*G**3*K**7*w**2/d**2 - 16*G**3*K**5 - 48*G**3*K**5*g**2/d**2 - 32*G**3*K**5*w**2/d**2 + 16*G**3*K**4*d**2*g/w**2 + 16*G**3*K**4*g**3/w**2 + 48*G**3*K**4*g - 16*G**3*K**4*g*w**2/d**2 - 4*G**3*K**2*g - 256*G**2*K**10*d**2/w**2 - 2304*G**2*K**10*g**2/w**2 - 1536*G**2*K**10 - 3840*G**2*K**10*g**4/(d**2*w**2) - 15360*G**2*K**10*g**2/d**2 - 3072*G**2*K**10*w**2/d**2 - 1792*G**2*K**10*g**6/(d**4*w**2) - 17920*G**2*K**10*g**4/d**4 - 23040*G**2*K**10*g**2*w**2/d**4 - 2048*G**2*K**10*w**4/d**4 - 192*G**2*K**7*d**2*g/w**2 - 384*G**2*K**7*g**3/w**2 - 1152*G**2*K**7*g - 192*G**2*K**7*g**5/(d**2*w**2) - 1920*G**2*K**7*g**3/d**2 - 1536*G**2*K**7*g*w**2/d**2 + 32*G**2*K**5*g + 32*G**2*K**5*g**3/d**2 + 96*G**2*K**5*g*w**2/d**2 - 4*G**2*K**4*d**4/w**2 - 8*G**2*K**4*d**2*g**2/w**2 - 16*G**2*K**4*d**2 - 4*G**2*K**4*g**4/w**2 - 48*G**2*K**4*g**2 - 8*G**2*K**4*w**2 + 24*G**2*K**4*g**2*w**2/d**2 + 16*G**2*K**4*w**4/d**2 + 2*G**2*K**2*d**2 + 2*G**2*K**2*g**2 + 4*G**2*K**2*w**2 + 512*G*K**10*d**2*g/w**2 + 1536*G*K**10*g**3/w**2 + 4608*G*K**10*g + 1536*G*K**10*g**5/(d**2*w**2) + 15360*G*K**10*g**3/d**2 + 12288*G*K**10*g*w**2/d**2 + 512*G*K**10*g**7/(d**4*w**2) + 10752*G*K**10*g**5/d**4 + 30720*G*K**10*g**3*w**2/d**4 + 10240*G*K**10*g*w**4/d**4 + 32*G*K**7*d**4/w**2 + 96*G*K**7*d**2*g**2/w**2 + 192*G*K**7*d**2 + 96*G*K**7*g**4/w**2 + 1152*G*K**7*g**2 + 384*G*K**7*w**2 + 32*G*K**7*g**6/(d**2*w**2) + 960*G*K**7*g**4/d**2 + 2304*G*K**7*g**2*w**2/d**2 + 256*G*K**7*w**4/d**2 - 8*G*K**5*d**2 - 16*G*K**5*g**2 - 32*G*K**5*w**2 - 8*G*K**5*g**4/d**2 - 96*G*K**5*g**2*w**2/d**2 - 32*G*K**5*w**4/d**2 + 16*G*K**4*d**2*g + 16*G*K**4*g**3 + 16*G*K**4*g*w**2 - 16*G*K**4*g**3*w**2/d**2 - 48*G*K**4*g*w**4/d**2 - 4*G*K**2*g*w**2 - 64*K**10*d**4/w**2 - 256*K**10*d**2*g**2/w**2 - 512*K**10*d**2 - 384*K**10*g**4/w**2 - 4608*K**10*g**2 - 1536*K**10*w**2 - 256*K**10*g**6/(d**2*w**2) - 7680*K**10*g**4/d**2 - 18432*K**10*g**2*w**2/d**2 - 2048*K**10*w**4/d**2 - 64*K**10*g**8/(d**4*w**2) - 3584*K**10*g**6/d**4 - 23040*K**10*g**4*w**2/d**4 - 20480*K**10*g**2*w**4/d**4 - 1024*K**10*w**6/d**4 - 192*K**7*d**2*g - 384*K**7*g**3 - 768*K**7*g*w**2 - 192*K**7*g**5/d**2 - 1536*K**7*g**3*w**2/d**2 - 768*K**7*g*w**4/d**2 + 32*K**5*g*w**2 + 32*K**5*g**3*w**2/d**2 + 64*K**5*g*w**4/d**2 + 4*K**4*d**2*w**2 - 8*K**4*g**2*w**2 + 16*K**4*w**4 + 4*K**4*g**4*w**2/d**2 + 48*K**4*g**2*w**4/d**2 + 16*K**4*w**6/d**2 + 512*K**10*d**2*g/G + 1536*K**10*g**3/G + 3072*K**10*g*w**2/G + 1536*K**10*g**5/(G*d**2) + 12288*K**10*g**3*w**2/(G*d**2) + 6144*K**10*g*w**4/(G*d**2) + 512*K**10*g**7/(G*d**4) + 9216*K**10*g**5*w**2/(G*d**4) + 20480*K**10*g**3*w**4/(G*d**4) + 4096*K**10*g*w**6/(G*d**4) + 384*K**7*g**2*w**2/G + 384*K**7*g**4*w**2/(G*d**2) + 768*K**7*g**2*w**4/(G*d**2) - 32*K**5*g**2*w**4/(G*d**2) - 16*K**4*g*w**4/G - 16*K**4*g**3*w**4/(G*d**2) - 32*K**4*g*w**6/(G*d**2) - 1536*K**10*g**2*w**2/G**2 - 3072*K**10*g**4*w**2/(G**2*d**2) - 6144*K**10*g**2*w**4/(G**2*d**2) - 1536*K**10*g**6*w**2/(G**2*d**4) - 10240*K**10*g**4*w**4/(G**2*d**4) - 6144*K**10*g**2*w**6/(G**2*d**4) - 256*K**7*g**3*w**4/(G**2*d**2) + 16*K**4*g**2*w**6/(G**2*d**2) + 2048*K**10*g**3*w**4/(G**3*d**2) + 2048*K**10*g**5*w**4/(G**3*d**4) + 4096*K**10*g**3*w**6/(G**3*d**4) - 1024*K**10*g**4*w**6/(G**4*d**4))
a = expand(4*G**2*K**3/d - 8*G*K**3*g/d - G*d + 4*K**3*d + 4*K**3*g**2/d + 8*K**3*w**2/d - 8*K**3*g*w**2/(G*d))
# Out:
#    2  3        3                       3  2      3  2      3    2
# 4⋅G ⋅K    8⋅G⋅K ⋅g            3     4⋅K ⋅g    8⋅K ⋅w    8⋅K ⋅g⋅w
# ─────── - ──────── - G⋅d + 4⋅K ⋅d + ─────── + ─────── - ─────────
#    d         d                         d         d         G⋅d

# %%
a = a/G/d
for i in range(7):
    print(sqrt_by_hand.coeff(K,i))
# Out:
# 0
# 0
# 2*G**4 - 4*G**3*g + 2*G**2*d**2 + 2*G**2*g**2 + 4*G**2*w**2 - 4*G*g*w**2
# 0
# -4*G**6/w**2 + 16*G**5*g/w**2 - 8*G**4*d**2/w**2 - 24*G**4*g**2/w**2 - 16*G**4 + 4*G**4*w**2/d**2 + 16*G**3*d**2*g/w**2 + 16*G**3*g**3/w**2 + 48*G**3*g - 16*G**3*g*w**2/d**2 - 4*G**2*d**4/w**2 - 8*G**2*d**2*g**2/w**2 - 16*G**2*d**2 - 4*G**2*g**4/w**2 - 48*G**2*g**2 - 8*G**2*w**2 + 24*G**2*g**2*w**2/d**2 + 16*G**2*w**4/d**2 + 16*G*d**2*g + 16*G*g**3 + 16*G*g*w**2 - 16*G*g**3*w**2/d**2 - 48*G*g*w**4/d**2 + 4*d**2*w**2 - 8*g**2*w**2 + 16*w**4 + 4*g**4*w**2/d**2 + 48*g**2*w**4/d**2 + 16*w**6/d**2 - 16*g*w**4/G - 16*g**3*w**4/(G*d**2) - 32*g*w**6/(G*d**2) + 16*g**2*w**6/(G**2*d**2)
# -8*G**5/d**2 + 32*G**4*g/d**2 - 16*G**3 - 48*G**3*g**2/d**2 - 32*G**3*w**2/d**2 + 32*G**2*g + 32*G**2*g**3/d**2 + 96*G**2*g*w**2/d**2 - 8*G*d**2 - 16*G*g**2 - 32*G*w**2 - 8*G*g**4/d**2 - 96*G*g**2*w**2/d**2 - 32*G*w**4/d**2 + 32*g*w**2 + 32*g**3*w**2/d**2 + 64*g*w**4/d**2 - 32*g**2*w**4/(G*d**2)
# 0

# %%
x_num_K = lambdify([d,K,w,g,G],x_approx_K)
y_num_K = lambdify([d,K,w,g,G],y_final.removeO())
xbsp = x_num_K(d=1.2,K=0.1,w=0.5,g=1,G=0.8)
ybsp= y_num_K(d=1.2,K=0.1,w=0.5,g=1,G=0.8)

xbsp, ybsp
# Out:
# (0.045166666666666695, -0.011817753667428354)

# %%
eq1_num = lambdify([x,y,d,K,w,g,G],eq1)
eq2_num = lambdify([x,y,d,K,w,g,G],eq2)
eq1_num(x=xbsp, y=ybsp,d=1.2,K=0.1,w=0.5,g=1,G=0.8), eq2_num(x=xbsp, y=ybsp,d=1.2,K=0.1,w=0.5,g=1,G=0.8)
# Out:
# (0.004866910015911002, -0.22614744147409124)

# %%
x_approx_w = solve(eq8.removeO(),x)
x_approx_w
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢0, - ────────────────────────────────────────────────────────────────────────
# ⎢                     ________________________________________________________
# ⎢                    ╱
# ⎢                   ╱
# ⎢                  ╱
# ⎢                 ╱
# ⎢                ╱
# ⎢               ╱
# ⎢              ╱                                                             ╱
# ⎢             ╱                                 2  3                        ╱
# ⎢            ╱                              27⋅G ⋅d                       ╲╱
# ⎢     3⋅    ╱          - ────────────────────────────────────────────── + ────
# ⎢          ╱               ⎛     3         4        3           2  2  ⎞
# ⎢       3 ╱              2⋅⎝8⋅G⋅K ⋅w + 12⋅K ⋅w - 8⋅K ⋅g⋅w + 12⋅K ⋅d ⋅w⎠
# ⎣       ╲╱
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ...

# %%
with open('x_approx_w.txt','w') as x_file:
    print(x_approx_w,file=x_file)

# %%
y_approx_w= series(sol_y[0],w,0,n=3)
y_approx_w = expand(y_approx_w).subs(x,x_approx_w)
y_approx_w = simplify(expand(series(expand(y_approx_w),w,0,n=3)))
y_approx_w

# %%
x_num = lambdify([d,K,w,g,G],x_approx_w)
y_num = lambdify([d,K,w,g,G],y_approx_w)
xbsp = x_num(d=1,K=1,w=0.1,g=1,G=0.5)
ybsp= y_num(d=1,K=1,w=0.1,g=1,G=0.5)

xbsp, ybsp

# %%
eq1_num = lambdify([x,y,d,K,w,g,G],eq1)
eq2_num = lambdify([x,y,d,K,w,g,G],eq2)
eq1_num(x=xbsp, y=ybsp,d=1,K=1,w=0.1,g=1,G=0.5), eq2_num(x=xbsp, y=ybsp,d=1,K=1,w=0.1,g=1,G=0.5)

# %%
eq9 = series(expand(eq7),K,0,n=5)
eq9 = simplify(expand(eq9))
eq9

# %%
x_approx_K = solve(eq9,x)
x_approx_K = series(expand(x_approx_K),K,0,n=3)

# %%
y_approx_w= series(sol_y[0],w,0,n=3)
y_approx_w = expand(y_approx_w).subs(x,x_approx_w)
y_approx_w = simplify(expand(y_approx_w))

# %%
y_final = expand(sol_y[0]).subs(x,sol_x[1])
y_final = simplify(expand(y_final))
sol_x[1], y_final
# Out:
# ⎛                                                                  ⎛
# ⎜                                                                  ⎜
# ⎜                                                                  ⎜
# ⎜                                                                  ⎜         ╱
# ⎜  ⎛                        ____________________________⎞  (G - g)⋅⎜√2⋅K⋅   ╱
# ⎜  ⎜   2                   ╱   ⎛   2        2        2⎞ ⎟          ⎜       ╱
# ⎜d⋅⎝2⋅G  + G⋅K - 2⋅G⋅g - ╲╱  G⋅⎝G⋅K  - 4⋅G⋅w  + 4⋅g⋅w ⎠ ⎠          ⎝     ╲╱
# ⎜────────────────────────────────────────────────────────, ───────────────────
# ⎜                     4⋅K⋅w⋅(G - g)
# ⎜
# ⎝
#
#   ____________________________________________________________________________
#  ╱   ⎛
# ╱    ⎜ 2  2         ⎛ 3      2          2    3⎞ ⎛ 4      3        2  2
#    G⋅⎝G ⋅d ⋅(G - g)⋅⎝G  - 3⋅G ⋅g + 3⋅G⋅g  - g ⎠⋅⎝G  - 4⋅G ⋅g + 6⋅G ⋅g  - 4⋅G⋅g
#    ───────────────────────────────────────────────────────────────────────────
#
#
# ...

# %%
x_num = lambdify([d,K,w,g,G],sol_x[1])
y_num = lambdify([x,d,K,w,g,G],sol_y[0])
y_num_test = lambdify([d,K,w,g,G],y_final)
eq1_num = lambdify([x,y,d,K,w,g,G],eq1)
eq2_num = lambdify([x,y,d,K,w,g,G],eq2)

# %%
xbsp = x_num(d=1,K=1,w=1,g=1,G=0.5)
ybsp= y_num(x=xbsp,d=1,K=1,w=1,g=1,G=0.5)
y_test = y_num_test(d=1,K=1,w=1,g=1,G=0.5)
xbsp, ybsp, y_test
# Out:
# (0.5590169943749475, 0.6734644042298626, 0.6734644042298605)

# %%
eq1_num(x=xbsp, y=ybsp,d=1,K=1,w=1,g=1,G=0.5), eq2_num(x=xbsp, y=ybsp,d=1,K=1,w=1,g=1,G=0.5)
# Out:
# (-0.0934592988263262, -0.11259319776886056)

# %%
print(eq7)
eq8 = (G**3*d**2*(x**2 - 2*g*x**2 + g**2*x**2 - d*w*x + d**2*x**2 + 2*K*x**2 - 2*K*g*x**2 + K**2*x**2 )/4 + G**2*K**2*d*w*x**3*(K - g + 1) + G**2*K*d**2*w*x**2*(2*d*x - 3*w)/2 + G*K**3*w**2*x**4*(3*K - 2*g + 2) + G*d**2*w**2*x*(2*K**2*x**3 + I*Abs(G*d*x))/2 + 2*I*K**2*w**2*x**3*(-K + g - 1)*Abs(G*d*x))/(G**3*d**2)
eq8 = simplify(expand(eq8))
sol_x = solve(eq8,x)
eq9 = simplify(series(sol_x[0].expand(),w,0,n=2))
eq9
# Out:
# (G**3*d**2*(x**2 - 2*g*x**2 + g**2*x**2 - d*w*x + d**2*x**2 + 2*K*x**2 - 2*K*g*x**2 + K**2*x**2 + O(w**3))/4 + G**2*K**2*d*w*x**3*(K - g + 1) + G**2*K*d**2*w*x**2*(2*d*x - 3*w)/2 + G*K**3*w**2*x**4*(3*K - 2*g + 2) + G*d**2*w**2*x*(2*K**2*x**3 + I*Abs(G*d*x))/2 + 2*I*K**2*w**2*x**3*(-K + g - 1)*Abs(G*d*x))/(G**3*d**2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 4
#       2 eq8 = (G**3*d**2*(x**2 - 2*g*x**2 + g**2*x**2 - d*w*x + d**2*x**2 + 2*K*x**2 - 2*K*g*x**2 + K**2*x**2 )/4 + G**2*K**2*d*w*x**3*(K - g + 1) + G**2*K*d**2*w*x**2*(2*d*x - 3*w)/2 + G*K**3*w**2*x**4*(3*K - 2*g + 2) + G*d**2*w**2*x*(2*K**2*x**3 + I*Abs(G*d*x))/2 + 2*I*K**2*w**2*x**3*(-K + g - 1)*Abs(G*d*x))/(G**3*d**2)
#       3 eq8 = simplify(expand(eq8))
# ----> 4 sol_x = solve(eq8,x)
#       5 eq9 = simplify(series(sol_x[0].expand(),w,0,n=2))
#       6 eq9
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
y1 = np.linspace(1/2-np.sqrt(5)/2+1/10**3,1/2+np.sqrt(5)/2-1/10**3,200)
y2 = np.linspace(2.2,3/2+np.sqrt(5)/2-0.01,200)
def x_sq(y):
    return 1+y-y**2
def f(y):
    return 9-2*y+y**2-4*y**3
def a(y):
    return 3*x_sq(y)+y**2-y-1
def b(y):
    return x_sq(y)+3*y**2-4*y
def c(y):
    return 2*y*np.sqrt(x_sq(y))-np.sqrt(x_sq(y))
def d(y):
    return 2*y*np.sqrt(x_sq(y))-2*np.sqrt(x_sq(y))
def lam1(y):
    return -(a(y)+b(y))/2-np.sqrt((a(y)+b(y))**2/4-a(y)*b(y)+c(y)*d(y))
def lam2(y):
    return -(a(y)+b(y))/2+np.sqrt((a(y)+b(y))**2/4-a(y)*b(y)+c(y)*d(y))
print(x_sq(0))
plt.figure()
plt.plot(y1,np.sqrt(x_sq(y1)),color='blue')
# plt.plot(y2,np.sqrt(x_sq(y2)),color='blue')
plt.show()
plt.figure()
plt.plot(y1,lam1(y1),color='blue')
plt.show()
# plt.figure()
# plt.plot(y2,lam1(y2),color='blue')
# plt.show()
plt.figure()
plt.plot(y1,lam2(y1),color='blue')
plt.show()
# plt.figure()
# plt.plot(y2,lam2(y2),color='blue')
# plt.show()
# Out:
# 1

# %%
0.5*(1+np.sqrt(5))
# Out:
# 1.618033988749895
